# %%
import cv2 as cv
from matplotlib import pyplot as plt
from feature_det_matching import FeatureDetector, ObjectLocalizer
import utilities as u

# %%
img1 = cv.imread(u.IMG_FOLDER_PATH1+'goose11.jpg',
                    cv.IMREAD_GRAYSCALE)
img2 = cv.imread(u.IMG_FOLDER_PATH1+'goose46.jpg',
                    cv.IMREAD_GRAYSCALE)

# %%
fd = FeatureDetector(img1, img2, 1000)
fd.draw_keypoints(1)

# %%
fd.draw_keypoints()

# %%
fm = ObjectLocalizer(img1, img2, 1000)
matches = fm.match(0.8)

# %%
scene_corners, matches_mask = fm.localize()
scene_corners
# Out:
# array([[[2498.0535, 1359.9453]],
#
#        [[2498.0925, 1359.9951]],
#
#        [[2498.049 , 1359.943 ]],
#
#        [[2498.1   , 1360.0012]]], dtype=float32)

# %%
plt.figure(figsize=(20,20))
fm.draw_matches(scene_corners, matches_mask)
