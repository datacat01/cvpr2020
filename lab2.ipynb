# %%
import cv2 as cv
from matplotlib import pyplot as plt
from feature_det_matching import FeatureDetector, ObjectLocalizer
import utilities as u

# %%
img1 = cv.imread(u.IMG_FOLDER_PATH1+'standard_up1.jpg',
                    cv.IMREAD_GRAYSCALE)
img2 = cv.imread(u.IMG_FOLDER_PATH1+'standard_up2.jpg',
                    cv.IMREAD_GRAYSCALE)

# %%
fd = FeatureDetector(img1, img2, 1000)
fd.draw_keypoints(1)

# %%
fd.draw_keypoints()

# %%
fm = ObjectLocalizer(img1, img2, 1000)
matches = fm.match(0.8)

# %%
scene_corners, matches_mask = fm.localize()
scene_corners
# Out:
# array([[[-115303.21   ,  -74275.914  ]],
#
#        [[   4004.153  ,     251.04585]],
#
#        [[   3230.6074 ,    2660.7097 ]],
#
#        [[   2374.9397 ,     926.5856 ]]], dtype=float32)

# %%
plt.figure(figsize=(20,20))
fm.draw_matches(scene_corners, matches_mask)
